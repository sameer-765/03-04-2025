# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car_price_performance.csv')

# %%
 df.head()
# Out:
#      Brand  Price  Horsepower  Fuel Efficiency
# 0  Brand C  91942         382             15.3
# 1  Brand A  70075         197             32.6
# 2  Brand C  84524         188             34.9
# 3  Brand E  68939         258             15.1
# 4  Brand X  66505         277             13.0

# %%
brand_avg_price = df.groupby('Brand')['Price'].mean().sort_values()
brand_avg_price
# Out:
# Brand
# Brand W    63034.557018
# Brand E    63712.542601
# Brand Y    63880.171569
# Brand A    64224.495370
# Brand B    64686.641350
# Brand C    64707.967890
# Brand Z    65244.331818
# Brand X    65405.884259
# Brand D    65498.701681
# Name: Price, dtype: float64

# %%
brand_mapping = {brand: i for i, brand in enumerate(brand_avg_price.index, start=1)}
brand_mapping
# Out:
# {'Brand W': 1,
#  'Brand E': 2,
#  'Brand Y': 3,
#  'Brand A': 4,
#  'Brand B': 5,
#  'Brand C': 6,
#  'Brand Z': 7,
#  'Brand X': 8,
#  'Brand D': 9}

# %%
encoded_brands = []
for b in df['Brand']:
    encoded_value = brand_mapping[b]
    encoded_brands.append(encoded_value)

# %%
df['Encoded_Brand'] = encoded_brands
df[['Brand', 'Encoded_Brand']].drop_duplicates()
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
# [2000 rows x 5 columns]

# %%
min_brand = df['Encoded_Brand'].min()
max_brand = df['Encoded_Brand'].max()
df['Scaled_Brand'] = (df['Encoded_Brand'] - min_brand) / (max_brand - min_brand)
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand  Scaled_Brand
# 0     Brand C  91942         382             15.3              6         0.625
# 1     Brand A  70075         197             32.6              4         0.375
# 2     Brand C  84524         188             34.9              6         0.625
# 3     Brand E  68939         258             15.1              2         0.125
# 4     Brand X  66505         277             13.0              8         0.875
# ...       ...    ...         ...              ...            ...           ...
# 1995  Brand Z  34535         196             15.2              7         0.750
# 1996  Brand C  35215         377             25.3              6         0.625
# 1997  Brand E  72980         294             21.8              2         0.125
# 1998  Brand Z  55921         443             11.0              7         0.750
# 1999  Brand B  95051         225             12.4              5         0.500
#
# [2000 rows x 6 columns]

# %%
min_hp = df['Horsepower'].min()
max_hp = df['Horsepower'].max()
df['Scaled_Horsepower'] = (df['Horsepower'] - min_hp) / (max_hp - min_hp)
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled_Brand  Scaled_Horsepower
# 0            0.625             0.7050
# 1            0.375             0.2425
# 2            0.625             0.2200
# ...

# %%
min = df['Fuel Efficiency'].min()
max = df['Fuel Efficiency'].max()
df['Scaled_Fuel_Efficiency'] = (df['Fuel Efficiency'] - min) / (max - min)
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled_Brand  Scaled_Horsepower  Scaled_Fuel_Efficiency
# 0            0.625             0.7050                   0.212
# ...

# %%
df['Performance_Index'] = df['Horsepower'] * df['Fuel Efficiency']
df
# Out:
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled_Brand  Scaled_Horsepower  Scaled_Fuel_Efficiency  \
# 0            0.625             0.7050                   0.212
# ...

# %%
print("final_Table")
df
# Out:
# final_Table
#         Brand  Price  Horsepower  Fuel Efficiency  Encoded_Brand  \
# 0     Brand C  91942         382             15.3              6
# 1     Brand A  70075         197             32.6              4
# 2     Brand C  84524         188             34.9              6
# 3     Brand E  68939         258             15.1              2
# 4     Brand X  66505         277             13.0              8
# ...       ...    ...         ...              ...            ...
# 1995  Brand Z  34535         196             15.2              7
# 1996  Brand C  35215         377             25.3              6
# 1997  Brand E  72980         294             21.8              2
# 1998  Brand Z  55921         443             11.0              7
# 1999  Brand B  95051         225             12.4              5
#
#       Scaled_Brand  Scaled_Horsepower  Scaled_Fuel_Efficiency  \
# 0            0.625             0.7050                   0.212
# ...

# %%
print("final_Table")
final_Table = df # Assign the dataframe 'df' to the variable 'final_Table'
final_Table.to_csv('final_car_table.csv', index=False)
from google.colab import files
files.download('final_car_table.csv')
# Out:
# final_Table
